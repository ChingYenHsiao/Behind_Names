# %% [markdown]
# (1) Import library

# %%
from collections import Counter
import numpy as np
import pandas as pd
from pathlib import Path as path_lib
import pickle

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import classification_report
from sklearn import metrics

from name_module.preprocess import *
from name_module.share_lib import reduce_mem_usage, restore_df_dtypes
from name_module.training_module import *


pd.options.display.float_format = '{:,.4f}'.format

# %% [markdown]
# (2) Read Files and construct Feature for name classifier

# %% [markdown]
# (2-1A) Read raw Taiwanese dataset

# %%
data_path = plib_path("./name_data/")
file_name = "Real_Name_data.csv"
name_df = pd.read_csv(data_path / file_name)
name_df.head()
# Out:
#   name  BirthYear FirstName LastName  gender  message  userID
# 0  丁承先          0        承先        丁       1     1940     nan
# 1  丁昞原          0        昞原        丁       1     1940     nan
# 2  方九龍          0        九龍        方       1     1940     nan
# 3  方大錚          0        大錚        方       1     1940     nan
# 4  方文隆          0        文隆        方       1     1940     nan

# %%
name_df = preprocess(name_df, data_path, file_name)
# Out:
# Drop Message is not number:  1660848 -> 1660848  drop: 0
# Drop English name: from  1660848 -> 1653057  drop: 7791
# Drop last name is not in Taiwan last name list : 1653057 -> 1653057  drop: 0
# Drop First name is longer than 3  : 1653057 -> 1653057  drop: 0
# Add W2V feature
# Memory usage of properties dataframe is : 2623.2593994140625  MB
# Memory usage is:  1330.547435760498  MB
# This is  50.72115384615385 % of the initial size
# w2v_feature len 200
# Add phonetic feature
# phonetic_feature len: 322
# Add fortune map feature
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  嘺 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禢 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  顔 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  嘺 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禢 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  顔 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  嘺 get stroke count failed!
# Error:  嘺 get stroke count failed!
# Error:  嘺 get stroke count failed!
# Error:  嘺 get stroke count failed!
# Error:  嘺 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  厙 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禢 get stroke count failed!
# Error:  禢 get stroke count failed!
# Error:  禢 get stroke count failed!
# Error:  禢 get stroke count failed!
# Error:  禢 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  禤 get stroke count failed!
# Error:  顔 get stroke count failed!
# Error:  顔 get stroke count failed!
# Error:  顔 get stroke count failed!
# Error:  顔 get stroke count failed!
# Error:  顔 get stroke count failed!
# len on fortune_map_feature_list: 27
# Add radical feature
# len of Radical_feature_list:  410
# Add zodiac feature
# len of Zodiac_feature_list:  12
# Memory usage of properties dataframe is : 2571.235625267029  MB
# Memory usage is:  2552.317889213562  MB
# This is  99.26425505824648 % of the initial size

# %%
gender_model_name = "WPF_gender_RFC_model.pkl"
with open('./TrainedModel/{}'.format(gender_model_name), 'rb') as handle:
    gender_model = pickle.loads(handle.read())
gender_x_feature_name = "WPF_gender_RFC_feature.pkl"
with open('./TrainedModel/{}'.format(gender_x_feature_name), 'rb') as handle:
    gender_x_feature = pickle.loads(handle.read())

# %%
name_df = add_gender_feature(name_df, gender_model, gender_x_feature)
name_df.head()
# Out:
#   name  BirthYear FirstName LastName  gender  message  userID  FN1_wv_0  \
# 0  丁承先          0        承先        丁       1     1940     nan   -0.0828
# 1  丁昞原          0        昞原        丁       1     1940     nan   -1.4421
# 2  方九龍          0        九龍        方       1     1940     nan    3.7893
# 3  方大錚          0        大錚        方       1     1940     nan    3.8134
# 4  方文隆          0        文隆        方       1     1940     nan    2.7781
#
#    FN2_wv_0  FN1_wv_1  ...  Zodiac_鼠  Zodiac_龍  FN1_Vowel_  FN1_Vowel_e  \
# 0   -5.7964    4.7822  ...         0         1           0            0
# 1    0.3820    1.2154  ...         0         1           0            0
# 2   -2.9803   -1.8931  ...         0         1           0            0
# 3   -4.7197   -0.9371  ...         0         1           0            0
# 4    3.8124    0.4082  ...         0         1           0            0
#
#    FN1_Vowel_en  FN1_Vowel_uǎ  FN2_Vowel_en  FN2_Vowel_uǎi  Male_prob  \
# 0             0             0             0              0     0.5938
# 1             0             0             0              0     0.6094
# 2             0             0             0              0     0.4688
# 3             0             0             0              0     0.5000
# 4             0             0             0              0     0.4688
#
#    Female_prob
# 0       0.4062
# 1       0.3906
# 2       0.5312
# 3       0.5000
# 4       0.5312
#
# [5 rows x 988 columns]

# %% [markdown]
# (2-1B) Read sampled dataset as base for comparing methods

# %%
with open('./NameData/thesis_experiment/TaiwanNames_real_Name/final_real_name_df', 'rb') as handle:
     name_df = pickle.loads(handle.read())
with open('./NameData/thesis_experiment/TaiwanNames_real_Name/test_index', 'rb') as handle:
     test_index = pickle.loads(handle.read())
with open('./NameData/thesis_experiment/TaiwanNames_real_Name/train_index', 'rb') as handle:
     train_index = pickle.loads(handle.read())

# %%
name_df
# Out:
#        FirstName  message name  FN1  FN2 FN1_muin FN2_muin  BirthYear  \
# 0             秀珠     1947  吳秀珠   70  596       iù        ū          1
# 1             豐博     1945  林豐博  277   72      ēng        ó          1
# 2             義勝     1945  康義勝  650  156        ì      èng          1
# 3              麗     1946   吳麗   -1  203       -1        ì          1
# 5             世慶     1947  林世慶  537  269        ì      ìng          1
# ...          ...      ...  ...  ...  ...      ...      ...        ...
# 320775        月鳳     1974  陳月鳳  706  598       uè      èng          6
# 320776        麗君     1974  吳麗君  203  153        ì       ūn          6
# 320777        玉淑     1974  陳玉淑  211  348        ù        ú          6
# 320778        明珠     1974  陳明珠  159  596      íng        ū          6
# 320779        曉貞     1974  陳曉貞  302  635      iǎo       ēn          6
#
#         GuessedGender  BFN12P  ...  FirstName1_ratio_6  FirstName2_ratio_6  \
# 0                   0       1  ...              0.0148              0.0050
# 1                   1       6  ...              0.0024              0.0011
# 2                   1       1  ...              0.0032              0.0032
# 3                   0       6  ...              0.0027              0.0151
# 5                   1       6  ...              0.0046              0.0041
# ...               ...     ...  ...                 ...                 ...
# 320775              0       6  ...              0.0040              0.0051
# 320776              0       6  ...              0.0151              0.0062
# 320777              0       6  ...              0.0149              0.0225
# 320778              0       1  ...              0.0165              0.0050
# 320779              0       6  ...              0.0028              0.0042
#
#         FirstName1_ratio_7  FirstName2_ratio_7  FirstName1_ratio_8  \
# 0                   0.0052              0.0010              0.0044
# 1                   0.0008              0.0010              0.0010
# 2                   0.0017              0.0010              0.0015
# 3                   0.0015              0.0022              0.0043
# 5                   0.0042              0.0014              0.0033
# ...                    ...                 ...                 ...
# 320775              0.0011              0.0012              0.0008
# 320776              0.0022              0.0080              0.0022
# 320777              0.0070              0.0078              0.0060
# 320778              0.0121              0.0010              0.0090
# 320779              0.0022              0.0020              0.0031
#
#         FirstName2_ratio_8  FirstName1_ratio_9  FirstName2_ratio_9  \
# 0                   0.0006              0.0021              0.0002
# 1                   0.0022              0.0007              0.0025
# 2                   0.0023              0.0009              0.0017
# 3                   0.0022              0.0073              0.0013
# 5                   0.0024              0.0022              0.0018
# ...                    ...                 ...                 ...
# 320775              0.0016              0.0005              0.0009
# 320776              0.0131              0.0013              0.0098
# 320777              0.0060              0.0031              0.0032
# 320778              0.0006              0.0058              0.0002
# 320779              0.0025              0.0021              0.0014
#
#         FirstName1_ratio_10  FirstName2_ratio_10
# 0                    0.0016               0.0001
# 1                    0.0007               0.0033
# 2                    0.0007               0.0012
# 3                    0.0125               0.0009
# 5                    0.0016               0.0019
# ...                     ...                  ...
# 320775               0.0003               0.0005
# 320776               0.0009               0.0077
# 320777               0.0026               0.0015
# 320778               0.0046               0.0001
# 320779               0.0012               0.0010
#
# [302432 rows x 3355 columns]

# %%
test_index
# Out:
# Int64Index([139458, 160569, 273443, 210241, 276709, 236523, 118678, 173062,
#             189727, 265777,
#             ...
#             270402, 126974,   5332, 117560,  65924, 148607,  58561, 259018,
#              89498, 194784],
#            dtype='int64', length=90730)

# %%
name_df = restore_df_dtypes(df=name_df,
                  int8_col=get_x_feature(['Phonetic','Fortune_map','Zodiac','Radical'], name_df),
                  int64_col=['BirthYear', 'message', 'gender', "BirthYear "],
                  float32_col=get_x_feature(['W2V'], name_df))
name_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302432 entries, 0 to 320779
# Columns: 3355 entries, FirstName to FirstName2_ratio_10
# dtypes: float32(200), float64(22), int64(6), int8(31), object(8), uint8(3088)
# memory usage: 1.2+ GB

# %%
name_df, zodiac_feature_list = add_zodiac_feature(name_df)
name_df = rename_old_name_df_dict(name_df)
# Out:
# len of Zodiac_feature_list:  12

# %% [markdown]
# (3) Resample dataset

# %%
# 2- A
Counter(name_df.BirthYear.tolist()).most_common()
# Out:
# [(9, 441855),
#  (8, 384205),
#  (10, 282646),
#  (7, 260573),
#  (3, 60274),
#  (4, 56392),
#  (2, 54838),
#  (5, 32236),
#  (1, 31419),
#  (6, 24279),
#  (0, 15678),
#  (11, 6620),
#  (12, 2037),
#  (13, 5)]

# %%
# 2- B
Counter(name_df.BirthYear.tolist()).most_common()

# %%
head = 1
tail = 10
BIRTH_YEAR_BASE = 1940
birth_year_base = BIRTH_YEAR_BASE + head * 5  
name_df["BirthYear"] = name_df.BirthYear.apply(lambda x: merge_birth_year(x, head, tail))

# %%
name_df["BirthYear"].value_counts()
# Out:
# 9     441855
# 8     384205
# 10    291308
# 7     260573
# 3      60274
# 4      56392
# 2      54838
# 1      47097
# 5      32236
# 6      24279
# Name: BirthYear, dtype: int64

# %% [markdown]
# (4)Preparing for traing model

# %% [markdown]
# (4-1) Make Feature Combinations

# %%
feature_list = ['W2V', 'Phonetic','Fortune_map','Zodiac','Radical']
feature_list_gender = ['W2V', 'Phonetic','Fortune_map','Zodiac','Radical','uni-gram']
feature_combinations = get_all_combinations(feature_list)

# %% [markdown]
# (4-2) Normalize w2v

# %%
w2v_feature = get_x_feature(['W2V'], name_df.columns)
print("Unnormalized W2V feature")
display(name_df[w2v_feature].describe())
name_df = w2v_normalize(name_df, w2v_feature)
print("Normalized W2V feature")
display(name_df[w2v_feature].describe())
# Out:
# Unnormalized W2V feature
#             FN1_wv_0       FN2_wv_0       FN1_wv_1       FN2_wv_1  \
# count 1,653,057.0000 1,653,057.0000 1,653,057.0000 1,653,057.0000
# mean         -1.4566        -1.3313         0.5142         1.2962
# std           3.5062         3.0327         3.5641         3.2839
# min         -14.5524       -14.5524       -15.1554       -15.1554
# 25%          -3.9635        -3.2677        -1.9196        -0.8918
# 50%          -1.2606        -1.4382         0.8509         1.6520
# 75%           0.6026         0.5287         3.1754         3.7534
# max          14.4414        13.8095        14.0238        14.6112
#
#             FN1_wv_2       FN2_wv_2       FN1_wv_3       FN2_wv_3  \
# count 1,653,057.0000 1,653,057.0000 1,653,057.0000 1,653,057.0000
# mean         -1.4798        -1.5367         0.9740         1.6704
# std           3.1358         3.1219         3.3813         3.1398
# min         -12.1204       -12.1204       -13.0599       -13.0599
# 25%          -3.3328        -3.6185        -1.0196        -0.2725
# 50%          -1.7088        -1.7895         1.3017         1.8901
# 75%           0.1622         0.2574         3.2359         3.8895
# max          13.6129        13.6129        15.6010        15.6010
#
#             FN1_wv_4       FN2_wv_4  ...      FN1_wv_95      FN2_wv_95  \
# count 1,653,057.0000 1,653,057.0000  ... 1,653,057.0000 1,653,057.0000
# mean          0.9617         0.5972  ...         0.9661         1.0064
# std           3.4673         2.9523  ...         3.5192         3.0769
# min         -19.8135       -19.8135  ...       -15.6760       -15.6760
# 25%          -0.8700        -1.1289  ...        -1.0049        -0.9547
# 50%           1.0117         0.8402  ...         1.3309         1.5669
# 75%           3.0144         2.3995  ...         3.3303         3.1105
# max          12.6033        12.6033  ...        13.2789        13.2789
#
#            FN1_wv_96      FN2_wv_96      FN1_wv_97      FN2_wv_97  \
# count 1,653,057.0000 1,653,057.0000 1,653,057.0000 1,653,057.0000
# mean         -0.9295        -1.1563         0.8766         0.6219
# std           3.3483         3.1693         3.7782         2.9574
# min         -13.2748       -13.2748       -12.7216       -12.7216
# 25%          -3.2001        -3.3835        -1.2209        -1.1163
# 50%          -1.0051        -1.4055         0.6738         0.4797
# 75%           1.2681         0.8089         2.9024         2.4191
# max          17.0671        17.0671        15.0147        15.0147
#
#            FN1_wv_98      FN2_wv_98      FN1_wv_99      FN2_wv_99
# count 1,653,057.0000 1,653,057.0000 1,653,057.0000 1,653,057.0000
# mean          1.1213         0.8172        -1.2455        -1.1376
# std           3.0133         2.7325         3.3068         3.2475
# min         -14.7658       -14.7658       -11.9364       -11.9364
# 25%          -1.0604        -0.8447        -3.6159        -3.2902
# 50%           0.9386         0.6370        -1.2016        -1.2813
# 75%           3.2944         2.7267         0.6677         0.8745
# max          13.4563        13.4563        14.5199        14.5199
#
# [8 rows x 200 columns]
# Normalized W2V feature
#             FN1_wv_0       FN2_wv_0       FN1_wv_1       FN2_wv_1  \
# count 1,653,057.0000 1,653,057.0000 1,653,057.0000 1,653,057.0000
# mean         -0.0000         0.0000        -0.0000        -0.0000
# std           1.0000         1.0000         1.0000         1.0000
# min          -3.7350        -4.3596        -4.3965        -5.0098
# 25%          -0.7150        -0.6385        -0.6829        -0.6663
# 50%           0.0559        -0.0353         0.0945         0.1083
# 75%           0.5873         0.6133         0.7467         0.7483
# max           4.5342         4.9926         3.7905         4.0547
#
#             FN1_wv_2       FN2_wv_2       FN1_wv_3       FN2_wv_3  \
# count 1,653,057.0000 1,653,057.0000 1,653,057.0000 1,653,057.0000
# mean          0.0000        -0.0000         0.0000        -0.0000
# std           1.0000         1.0000         1.0000         1.0000
# min          -3.3933        -3.3901        -4.1505        -4.6915
# 25%          -0.5909        -0.6668        -0.5896        -0.6188
# 50%          -0.0730        -0.0810         0.0969         0.0700
# 75%           0.5236         0.5747         0.6690         0.7068
# max           4.8130         4.8527         4.3259         4.4368
#
#             FN1_wv_4       FN2_wv_4  ...      FN1_wv_95      FN2_wv_95  \
# count 1,653,057.0000 1,653,057.0000  ... 1,653,057.0000 1,653,057.0000
# mean         -0.0000        -0.0000  ...        -0.0000        -0.0000
# std           1.0000         1.0000  ...         1.0000         1.0000
# min          -5.9918        -6.9135  ...        -4.7289        -5.4218
# 25%          -0.5283        -0.5847  ...        -0.5601        -0.6374
# 50%           0.0144         0.0823  ...         0.1036         0.1822
# 75%           0.5920         0.6105  ...         0.6718         0.6838
# max           3.3575         4.0667  ...         3.4987         3.9886
#
#            FN1_wv_96      FN2_wv_96      FN1_wv_97      FN2_wv_97  \
# count 1,653,057.0000 1,653,057.0000 1,653,057.0000 1,653,057.0000
# mean          0.0000         0.0000         0.0000         0.0000
# std           1.0000         1.0000         1.0000         1.0000
# min          -3.6870        -3.8237        -3.5991        -4.5119
# 25%          -0.6781        -0.7027        -0.5552        -0.5877
# 50%          -0.0226        -0.0786        -0.0537        -0.0481
# 75%           0.6563         0.6201         0.5362         0.6077
# max           5.3748         5.7499         3.7421         4.8667
#
#            FN1_wv_98      FN2_wv_98      FN1_wv_99      FN2_wv_99
# count 1,653,057.0000 1,653,057.0000 1,653,057.0000 1,653,057.0000
# mean         -0.0000         0.0000        -0.0000        -0.0000
# std           1.0000         1.0000         1.0000         1.0000
# min          -5.2722        -5.7029        -3.2330        -3.3253
# 25%          -0.7240        -0.6082        -0.7168        -0.6628
# 50%          -0.0606        -0.0660         0.0133        -0.0442
# 75%           0.7212         0.6988         0.5786         0.6196
# max           4.0935         4.6255         4.7676         4.8215
#
# [8 rows x 200 columns]

# %% [markdown]
# (5) Experiment - Train feature combination for RFC

# %% [markdown]
# (5-1 A) Training for all combination - resampled dataset

# %%
birth_year_base = BIRTH_YEAR_BASE + head * 5  
birth_years = [i for i in range(head, tail + 1)]  # for index to 1945 ~ 1994
# sample_number = name_df["BirthYear"].value_counts().min()
sample_number = 32236
target_names = [str(i) for i in range(birth_year_base, BIRTH_YEAR_BASE + tail * 5 + 5, 5)]
save_path = plib_path("./Training/Real/")
validation_times = 1
do_first_name_augmentation = False
estimators_num = 64
min_samples_leaf_num = 1
model_name = "Taiwan_name_RFC"
train_birth_year_model(name_df, do_first_name_augmentation, validation_times,
                           feature_combinations, BIRTH_YEAR_BASE, target_names,
                           save_path, model_name, birth_years, sample_number,
                           estimators_num, min_samples_leaf_num)
# Out:
# (322360, 988) 10
# Combination 0 Training feature category: ['W2V']
# len of x_feature: 200
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.5957820824675261
# macro precision_score ::  0.5975
# micro precision_score ::  0.5958
# macro recall_score ::  0.5958
# micro recall_score ::  0.5958
# macro F1_score ::  0.5958
# micro F1_score ::  0.5958
# dataset 有203086個名字 74315種名字
# Multi_Train Accuracy:: 0.9995962301685001
# 平均年份絕對值誤差:: 0.00408693853835321
# report:
#                precision    recall  f1-score   support
#
#         1945       0.65      0.67      0.66     20182
#         1950       0.60      0.62      0.61     20245
#         1955       0.61      0.58      0.60     20449
#         1960       0.57      0.58      0.58     20240
#         1965       0.54      0.58      0.56     20280
#         1970       0.52      0.61      0.56     20327
#         1975       0.57      0.53      0.55     20353
#         1980       0.61      0.54      0.57     20369
#         1985       0.64      0.59      0.61     20230
#         1990       0.66      0.66      0.66     20411
#
#     accuracy                           0.60    203086
#    macro avg       0.60      0.60      0.60    203086
# weighted avg       0.60      0.60      0.60    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.3025000574461729
# macro precision_score ::  0.2979
# micro precision_score ::  0.3025
# macro recall_score ::  0.3024
# micro recall_score ::  0.3025
# macro F1_score ::  0.2994
# micro F1_score ::  0.3025
# dataset 有87038個名字 43304種名字
# Multi_Test Accuracy:: 0.6078149773662078
# 平均年份絕對值誤差:: 3.9645672005331005
# report:
#                precision    recall  f1-score   support
#
#         1945       0.37      0.40      0.39      8773
#         1950       0.32      0.34      0.33      8811
#         1955       0.31      0.30      0.30      8671
#         1960       0.30      0.29      0.30      8679
#         1965       0.33      0.34      0.34      8767
#         1970       0.36      0.39      0.37      8738
#         1975       0.22      0.19      0.20      8723
#         1980       0.21      0.18      0.19      8605
#         1985       0.25      0.23      0.24      8764
#         1990       0.31      0.37      0.34      8507
#
#     accuracy                           0.30     87038
#    macro avg       0.30      0.30      0.30     87038
# weighted avg       0.30      0.30      0.30     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.3001923315547835
# macro precision_score ::  0.2953
# micro precision_score ::  0.3002
# macro recall_score ::  0.3
# micro recall_score ::  0.3002
# macro F1_score ::  0.2969
# micro F1_score ::  0.3002
# dataset 有32236個名字 20807種名字
# Multi_Development Accuracy:: 0.4962154113413575
# 平均年份絕對值誤差:: 5.145551557265169
# report:
#                precision    recall  f1-score   support
#
#         1945       0.38      0.42      0.40      3281
#         1950       0.31      0.34      0.32      3180
#         1955       0.30      0.29      0.29      3116
#         1960       0.29      0.28      0.29      3317
#         1965       0.33      0.33      0.33      3189
#         1970       0.35      0.39      0.37      3171
#         1975       0.20      0.17      0.19      3160
#         1980       0.22      0.18      0.20      3262
#         1985       0.26      0.24      0.25      3242
#         1990       0.32      0.36      0.34      3318
#
#     accuracy                           0.30     32236
#    macro avg       0.30      0.30      0.30     32236
# weighted avg       0.30      0.30      0.30     32236
#
# (322360, 988) 10
# Combination 1 Training feature category: ['Phonetic']
# len of x_feature: 328
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.43837093645056774
# macro precision_score ::  0.4383
# micro precision_score ::  0.4384
# macro recall_score ::  0.4385
# micro recall_score ::  0.4384
# macro F1_score ::  0.4374
# micro F1_score ::  0.4384
# dataset 有203086個名字 74597種名字
# Multi_Train Accuracy:: 0.8230848015126596
# 平均年份絕對值誤差:: 2.0348866982460634
# report:
#                precision    recall  f1-score   support
#
#         1945       0.52      0.54      0.53     20195
#         1950       0.50      0.48      0.49     20380
#         1955       0.46      0.45      0.45     20258
#         1960       0.45      0.42      0.44     20457
#         1965       0.42      0.45      0.43     20327
#         1970       0.40      0.46      0.43     20432
#         1975       0.38      0.36      0.37     20351
#         1980       0.40      0.33      0.36     20311
#         1985       0.42      0.40      0.41     20241
#         1990       0.44      0.50      0.47     20134
#
#     accuracy                           0.44    203086
#    macro avg       0.44      0.44      0.44    203086
# weighted avg       0.44      0.44      0.44    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.24904064891196948
# macro precision_score ::  0.2457
# micro precision_score ::  0.249
# macro recall_score ::  0.2489
# micro recall_score ::  0.249
# macro F1_score ::  0.2467
# micro F1_score ::  0.249
# dataset 有87038個名字 43319種名字
# Multi_Test Accuracy:: 0.535283439417266
# 平均年份絕對值誤差:: 5.196213148280061
# report:
#                precision    recall  f1-score   support
#
#         1945       0.32      0.34      0.33      8727
#         1950       0.28      0.27      0.28      8707
#         1955       0.24      0.23      0.24      8752
#         1960       0.24      0.23      0.23      8638
#         1965       0.26      0.27      0.26      8723
#         1970       0.26      0.30      0.28      8648
#         1975       0.18      0.17      0.17      8614
#         1980       0.18      0.15      0.17      8692
#         1985       0.21      0.20      0.20      8739
#         1990       0.29      0.33      0.31      8798
#
#     accuracy                           0.25     87038
#    macro avg       0.25      0.25      0.25     87038
# weighted avg       0.25      0.25      0.25     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.25300905819580594
# macro precision_score ::  0.2499
# micro precision_score ::  0.253
# macro recall_score ::  0.2528
# micro recall_score ::  0.253
# macro F1_score ::  0.2508
# micro F1_score ::  0.253
# dataset 有32236個名字 20875種名字
# Multi_Development Accuracy:: 0.4429519791537412
# 平均年份絕對值誤差:: 6.25716590147661
# report:
#                precision    recall  f1-score   support
#
#         1945       0.33      0.35      0.34      3314
#         1950       0.28      0.28      0.28      3149
#         1955       0.25      0.24      0.25      3226
#         1960       0.24      0.22      0.23      3141
#         1965       0.26      0.28      0.27      3186
#         1970       0.26      0.30      0.28      3156
#         1975       0.19      0.18      0.18      3271
#         1980       0.18      0.15      0.16      3233
#         1985       0.22      0.21      0.21      3256
#         1990       0.30      0.34      0.32      3304
#
#     accuracy                           0.25     32236
#    macro avg       0.25      0.25      0.25     32236
# weighted avg       0.25      0.25      0.25     32236
#
# (322360, 988) 10
# Combination 2 Training feature category: ['Fortune_map']
# len of x_feature: 27
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.154845730380233
# macro precision_score ::  0.2126
# micro precision_score ::  0.1548
# macro recall_score ::  0.1548
# micro recall_score ::  0.1548
# macro F1_score ::  0.1183
# micro F1_score ::  0.1548
# dataset 有203086個名字 74253種名字
# Multi_Train Accuracy:: 0.4535073811094807
# 平均年份絕對值誤差:: 6.881853008085245
# report:
#                precision    recall  f1-score   support
#
#         1945       0.15      0.25      0.19     20273
#         1950       0.15      0.23      0.18     20269
#         1955       0.15      0.23      0.18     20260
#         1960       0.15      0.06      0.09     20402
#         1965       0.15      0.05      0.08     20285
#         1970       0.13      0.09      0.11     20322
#         1975       0.12      0.06      0.08     20175
#         1980       0.80      0.00      0.00     20325
#         1985       0.16      0.01      0.02     20391
#         1990       0.17      0.57      0.27     20384
#
#     accuracy                           0.15    203086
#    macro avg       0.21      0.15      0.12    203086
# weighted avg       0.21      0.15      0.12    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.1469932673085319
# macro precision_score ::  0.2221
# micro precision_score ::  0.147
# macro recall_score ::  0.1469
# micro recall_score ::  0.147
# macro F1_score ::  0.1107
# micro F1_score ::  0.147
# dataset 有87038個名字 43249種名字
# Multi_Test Accuracy:: 0.36647211562765686
# 平均年份絕對值誤差:: 8.220983938050047
# report:
#                precision    recall  f1-score   support
#
#         1945       0.14      0.23      0.18      8702
#         1950       0.14      0.22      0.17      8783
#         1955       0.14      0.21      0.17      8771
#         1960       0.13      0.05      0.08      8657
#         1965       0.11      0.04      0.06      8700
#         1970       0.12      0.08      0.10      8694
#         1975       0.11      0.05      0.07      8742
#         1980       1.00      0.00      0.00      8674
#         1985       0.15      0.01      0.02      8648
#         1990       0.17      0.56      0.26      8667
#
#     accuracy                           0.15     87038
#    macro avg       0.22      0.15      0.11     87038
# weighted avg       0.22      0.15      0.11     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.14632708772800596
# macro precision_score ::  0.1212
# micro precision_score ::  0.1463
# macro recall_score ::  0.1471
# micro recall_score ::  0.1463
# macro F1_score ::  0.1106
# micro F1_score ::  0.1463
# dataset 有32236個名字 20954種名字
# Multi_Development Accuracy:: 0.2808661124208959
# 平均年份絕對值誤差:: 9.771001364933614
# report:
#                precision    recall  f1-score   support
#
#         1945       0.14      0.22      0.17      3261
#         1950       0.14      0.21      0.17      3184
#         1955       0.13      0.20      0.16      3205
#         1960       0.14      0.06      0.09      3177
#         1965       0.13      0.05      0.07      3251
#         1970       0.12      0.09      0.10      3220
#         1975       0.11      0.05      0.07      3319
#         1980       0.00      0.00      0.00      3237
#         1985       0.12      0.01      0.02      3197
#         1990       0.17      0.58      0.27      3185
#
#     accuracy                           0.15     32236
#    macro avg       0.12      0.15      0.11     32236
# weighted avg       0.12      0.15      0.11     32236
#
# (322360, 988) 10
# Combination 3 Training feature category: ['Zodiac']
# len of x_feature: 12
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.2810582708803167
# macro precision_score ::  0.1933
# micro precision_score ::  0.2811
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# macro recall_score ::  0.2812
# micro recall_score ::  0.2811
# macro F1_score ::  0.22
# micro F1_score ::  0.2811
# dataset 有203086個名字 74456種名字
# Multi_Train Accuracy:: 0.48639000226505025
# 平均年份絕對值誤差:: 7.097938804250416
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# report:
#                precision    recall  f1-score   support
#
#         1945       0.00      0.00      0.00     20342
#         1950       0.00      0.00      0.00     20222
#         1955       0.24      0.21      0.23     20216
#         1960       0.29      0.63      0.40     20277
#         1965       0.27      0.52      0.36     20319
#         1970       0.28      0.21      0.24     20406
#         1975       0.32      0.52      0.39     20278
#         1980       0.00      0.00      0.00     20430
#         1985       0.25      0.19      0.22     20242
#         1990       0.28      0.52      0.36     20354
#
#     accuracy                           0.28    203086
#    macro avg       0.19      0.28      0.22    203086
# weighted avg       0.19      0.28      0.22    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.28072795790344446
# macro precision_score ::  0.1932
# micro precision_score ::  0.2807
# macro recall_score ::  0.2799
# micro recall_score ::  0.2807
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# macro F1_score ::  0.2197
# micro F1_score ::  0.2807
# dataset 有87038個名字 43192種名字
# Multi_Test Accuracy:: 0.42668719409912914
# 平均年份絕對值誤差:: 8.380626852639077
# report:
#                precision    recall  f1-score   support
#
#         1945       0.00      0.00      0.00      8732
#         1950       0.00      0.00      0.00      8755
#         1955       0.24      0.21      0.22      8750
#         1960       0.30      0.63      0.40      8775
#         1965       0.27      0.51      0.35      8750
#         1970       0.27      0.20      0.23      8558
#         1975       0.32      0.52      0.40      8806
#         1980       0.00      0.00      0.00      8539
#         1985       0.27      0.21      0.24      8733
#         1990       0.27      0.52      0.35      8640
#
#     accuracy                           0.28     87038
#    macro avg       0.19      0.28      0.22     87038
# weighted avg       0.19      0.28      0.22     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy ::  0.27940811515076314
# macro precision_score ::  0.1926
# micro precision_score ::  0.2794
# macro recall_score ::  0.2811
# micro recall_score ::  0.2794
# macro F1_score ::  0.2192
# micro F1_score ::  0.2794
# dataset 有32236個名字 21084種名字
# Multi_Development Accuracy:: 0.3618314927410349
# 平均年份絕對值誤差:: 10.012656657153492
# report:
#                precision    recall  f1-score   support
#
#         1945       0.00      0.00      0.00      3162
#         1950       0.00      0.00      0.00      3259
#         1955       0.24      0.22      0.23      3270
#         1960       0.28      0.63      0.39      3184
#         1965       0.27      0.52      0.36      3167
#         1970       0.28      0.21      0.24      3272
#         1975       0.32      0.53      0.40      3152
#         1980       0.00      0.00      0.00      3267
#         1985       0.26      0.19      0.22      3261
#         1990       0.28      0.52      0.36      3242
#
#     accuracy                           0.28     32236
#    macro avg       0.19      0.28      0.22     32236
# weighted avg       0.19      0.28      0.22     32236
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (322360, 988) 10
# Combination 4 Training feature category: ['Radical']
# len of x_feature: 410
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.2551776094856366
# macro precision_score ::  0.2539
# micro precision_score ::  0.2552
# macro recall_score ::  0.2552
# micro recall_score ::  0.2552
# macro F1_score ::  0.2538
# micro F1_score ::  0.2552
# dataset 有203086個名字 74678種名字
# Multi_Train Accuracy:: 0.6064622869129335
# 平均年份絕對值誤差:: 5.057000482554189
# report:
#                precision    recall  f1-score   support
#
#         1945       0.29      0.33      0.31     20299
#         1950       0.26      0.26      0.26     20369
#         1955       0.25      0.22      0.24     20143
#         1960       0.25      0.23      0.24     20444
#         1965       0.25      0.25      0.25     20236
#         1970       0.24      0.25      0.24     20285
#         1975       0.23      0.20      0.21     20322
#         1980       0.23      0.22      0.23     20401
#         1985       0.26      0.25      0.26     20381
#         1990       0.28      0.34      0.31     20206
#
#     accuracy                           0.26    203086
#    macro avg       0.25      0.26      0.25    203086
# weighted avg       0.25      0.26      0.25    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.18123118637836347
# macro precision_score ::  0.1793
# micro precision_score ::  0.1812
# macro recall_score ::  0.1812
# micro recall_score ::  0.1812
# macro F1_score ::  0.1796
# micro F1_score ::  0.1812
# dataset 有87038個名字 43272種名字
# Multi_Test Accuracy:: 0.44808014890048026
# 平均年份絕對值誤差:: 6.935304120039523
# report:
#                precision    recall  f1-score   support
#
#         1945       0.22      0.25      0.23      8687
#         1950       0.18      0.18      0.18      8659
#         1955       0.17      0.15      0.16      8812
#         1960       0.16      0.14      0.15      8540
#         1965       0.18      0.18      0.18      8831
#         1970       0.18      0.19      0.19      8693
#         1975       0.16      0.14      0.15      8684
#         1980       0.15      0.14      0.14      8717
#         1985       0.18      0.18      0.18      8660
#         1990       0.21      0.26      0.23      8755
#
#     accuracy                           0.18     87038
#    macro avg       0.18      0.18      0.18     87038
# weighted avg       0.18      0.18      0.18     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.17986102494105968
# macro precision_score ::  0.1779
# micro precision_score ::  0.1799
# macro recall_score ::  0.1797
# micro recall_score ::  0.1799
# macro F1_score ::  0.1782
# micro F1_score ::  0.1799
# dataset 有32236個名字 20914種名字
# Multi_Development Accuracy:: 0.3540451668941556
# 平均年份絕對值誤差:: 8.276771311577118
# report:
#                precision    recall  f1-score   support
#
#         1945       0.22      0.25      0.24      3250
#         1950       0.19      0.19      0.19      3208
#         1955       0.17      0.15      0.16      3281
#         1960       0.16      0.15      0.15      3252
#         1965       0.17      0.17      0.17      3169
#         1970       0.19      0.19      0.19      3258
#         1975       0.15      0.13      0.14      3230
#         1980       0.15      0.14      0.14      3118
#         1985       0.17      0.18      0.17      3195
#         1990       0.20      0.25      0.22      3275
#
#     accuracy                           0.18     32236
#    macro avg       0.18      0.18      0.18     32236
# weighted avg       0.18      0.18      0.18     32236
#
# (322360, 988) 10
# Combination 5 Training feature category: ['W2V', 'Phonetic']
# len of x_feature: 528
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.5964763696168126
# macro precision_score ::  0.5981
# micro precision_score ::  0.5965
# macro recall_score ::  0.5964
# micro recall_score ::  0.5965
# macro F1_score ::  0.5965
# micro F1_score ::  0.5965
# dataset 有203086個名字 74217種名字
# Multi_Train Accuracy:: 0.9997144067045488
# 平均年份絕對值誤差:: 0.00361423239415814
# report:
#                precision    recall  f1-score   support
#
#         1945       0.64      0.67      0.66     20374
#         1950       0.61      0.62      0.61     20426
#         1955       0.59      0.59      0.59     20188
#         1960       0.60      0.56      0.58     20147
#         1965       0.52      0.59      0.55     20225
#         1970       0.54      0.60      0.57     20364
#         1975       0.58      0.52      0.55     20327
#         1980       0.58      0.56      0.57     20411
#         1985       0.64      0.58      0.61     20281
#         1990       0.67      0.66      0.67     20343
#
#     accuracy                           0.60    203086
#    macro avg       0.60      0.60      0.60    203086
# weighted avg       0.60      0.60      0.60    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.3060502309336152
# macro precision_score ::  0.3015
# micro precision_score ::  0.3061
# macro recall_score ::  0.3061
# micro recall_score ::  0.3061
# macro F1_score ::  0.303
# micro F1_score ::  0.3061
# dataset 有87038個名字 43353種名字
# Multi_Test Accuracy:: 0.6071256232909763
# 平均年份絕對值誤差:: 3.94362232588065
# report:
#                precision    recall  f1-score   support
#
#         1945       0.37      0.43      0.40      8668
#         1950       0.33      0.34      0.34      8605
#         1955       0.31      0.30      0.30      8727
#         1960       0.31      0.28      0.29      8865
#         1965       0.33      0.35      0.34      8809
#         1970       0.37      0.40      0.39      8688
#         1975       0.22      0.18      0.20      8690
#         1980       0.21      0.19      0.20      8676
#         1985       0.25      0.24      0.25      8653
#         1990       0.31      0.35      0.33      8657
#
#     accuracy                           0.31     87038
#    macro avg       0.30      0.31      0.30     87038
# weighted avg       0.30      0.31      0.30     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.30645861769450305
# macro precision_score ::  0.3022
# micro precision_score ::  0.3065
# macro recall_score ::  0.3066
# micro recall_score ::  0.3065
# macro F1_score ::  0.3037
# micro F1_score ::  0.3065
# dataset 有32236個名字 20832種名字
# Multi_Development Accuracy:: 0.5023886338255367
# 平均年份絕對值誤差:: 5.178868345948628
# report:
#                precision    recall  f1-score   support
#
#         1945       0.37      0.43      0.40      3194
#         1950       0.33      0.35      0.34      3205
#         1955       0.32      0.30      0.31      3321
#         1960       0.31      0.28      0.29      3224
#         1965       0.33      0.37      0.35      3202
#         1970       0.36      0.38      0.37      3184
#         1975       0.22      0.18      0.20      3219
#         1980       0.22      0.20      0.21      3149
#         1985       0.25      0.23      0.24      3302
#         1990       0.31      0.34      0.33      3236
#
#     accuracy                           0.31     32236
#    macro avg       0.30      0.31      0.30     32236
# weighted avg       0.30      0.31      0.30     32236
#
# (322360, 988) 10
# Combination 6 Training feature category: ['W2V', 'Fortune_map']
# len of x_feature: 227
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.7859527490816698
# macro precision_score ::  0.7864
# micro precision_score ::  0.786
# macro recall_score ::  0.7859
# micro recall_score ::  0.786
# macro F1_score ::  0.7858
# micro F1_score ::  0.786
# dataset 有203086個名字 74444種名字
# Multi_Train Accuracy:: 0.9999507597766464
# 平均年份絕對值誤差:: 0.00024620111676826567
# report:
#                precision    recall  f1-score   support
#
#         1945       0.85      0.85      0.85     20454
#         1950       0.82      0.82      0.82     20174
#         1955       0.81      0.81      0.81     20229
#         1960       0.81      0.79      0.80     20377
#         1965       0.74      0.80      0.77     20332
#         1970       0.75      0.80      0.77     20459
#         1975       0.77      0.71      0.74     20279
#         1980       0.76      0.73      0.74     20220
#         1985       0.77      0.76      0.76     20355
#         1990       0.79      0.79      0.79     20207
#
#     accuracy                           0.79    203086
#    macro avg       0.79      0.79      0.79    203086
# weighted avg       0.79      0.79      0.79    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.35995771961671913
# macro precision_score ::  0.3549
# micro precision_score ::  0.36
# macro recall_score ::  0.3603
# micro recall_score ::  0.36
# macro F1_score ::  0.357
# micro F1_score ::  0.36
# dataset 有87038個名字 43257種名字
# Multi_Test Accuracy:: 0.619683356694777
# 平均年份絕對值誤差:: 3.75247593005354
# report:
#                precision    recall  f1-score   support
#
#         1945       0.43      0.49      0.46      8527
#         1950       0.41      0.42      0.42      8835
#         1955       0.37      0.37      0.37      8667
#         1960       0.39      0.37      0.38      8793
#         1965       0.43      0.44      0.44      8743
#         1970       0.48      0.51      0.49      8571
#         1975       0.23      0.19      0.21      8754
#         1980       0.22      0.20      0.21      8657
#         1985       0.25      0.25      0.25      8676
#         1990       0.33      0.36      0.34      8815
#
#     accuracy                           0.36     87038
#    macro avg       0.35      0.36      0.36     87038
# weighted avg       0.35      0.36      0.36     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.35848120114158083
# macro precision_score ::  0.354
# micro precision_score ::  0.3585
# macro recall_score ::  0.359
# micro recall_score ::  0.3585
# macro F1_score ::  0.3559
# micro F1_score ::  0.3585
# dataset 有32236個名字 20834種名字
# Multi_Development Accuracy:: 0.5227695743888819
# 平均年份絕對值誤差:: 4.742803077304877
# report:
#                precision    recall  f1-score   support
#
#         1945       0.43      0.48      0.45      3255
#         1950       0.40      0.40      0.40      3227
#         1955       0.40      0.39      0.39      3340
#         1960       0.37      0.36      0.37      3066
#         1965       0.42      0.44      0.43      3161
#         1970       0.49      0.51      0.50      3206
#         1975       0.23      0.20      0.21      3203
#         1980       0.23      0.20      0.21      3359
#         1985       0.24      0.25      0.24      3205
#         1990       0.33      0.36      0.34      3214
#
#     accuracy                           0.36     32236
#    macro avg       0.35      0.36      0.36     32236
# weighted avg       0.35      0.36      0.36     32236
#
# (322360, 988) 10
# Combination 7 Training feature category: ['W2V', 'Zodiac']
# len of x_feature: 212
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.885846390199226
# macro precision_score ::  0.8865
# micro precision_score ::  0.8858
# macro recall_score ::  0.8858
# micro recall_score ::  0.8858
# macro F1_score ::  0.886
# micro F1_score ::  0.8858
# dataset 有203086個名字 74347種名字
# Multi_Train Accuracy:: 0.9999359877096402
# 平均年份絕對值誤差:: 0.0009700324000669667
# report:
#                precision    recall  f1-score   support
#
#         1945       0.89      0.88      0.89     20259
#         1950       0.89      0.90      0.89     20288
#         1955       0.88      0.87      0.88     20276
#         1960       0.88      0.88      0.88     20382
#         1965       0.84      0.88      0.86     20199
#         1970       0.84      0.89      0.87     20381
#         1975       0.89      0.87      0.88     20325
#         1980       0.90      0.87      0.89     20344
#         1985       0.93      0.92      0.93     20356
#         1990       0.92      0.90      0.91     20276
#
#     accuracy                           0.89    203086
#    macro avg       0.89      0.89      0.89    203086
# weighted avg       0.89      0.89      0.89    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.559479767457892
# macro precision_score ::  0.5595
# micro precision_score ::  0.5595
# macro recall_score ::  0.5595
# micro recall_score ::  0.5595
# macro F1_score ::  0.559
# micro F1_score ::  0.5595
# dataset 有87038個名字 43244種名字
# Multi_Test Accuracy:: 0.7186746018980216
# 平均年份絕對值誤差:: 3.7008318205841126
# report:
#                precision    recall  f1-score   support
#
#         1945       0.58      0.51      0.54      8731
#         1950       0.56      0.59      0.57      8673
#         1955       0.52      0.55      0.54      8715
#         1960       0.54      0.54      0.54      8675
#         1965       0.57      0.56      0.56      8778
#         1970       0.62      0.61      0.62      8669
#         1975       0.50      0.49      0.49      8707
#         1980       0.51      0.50      0.50      8672
#         1985       0.63      0.66      0.64      8658
#         1990       0.56      0.59      0.58      8760
#
#     accuracy                           0.56     87038
#    macro avg       0.56      0.56      0.56     87038
# weighted avg       0.56      0.56      0.56     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.5619803945898995
# macro precision_score ::  0.5615
# micro precision_score ::  0.562
# macro recall_score ::  0.562
# micro recall_score ::  0.562
# macro F1_score ::  0.5612
# micro F1_score ::  0.562
# dataset 有32236個名字 20908種名字
# Multi_Development Accuracy:: 0.6642263308102743
# 平均年份絕對值誤差:: 4.521932001489018
# report:
#                precision    recall  f1-score   support
#
#         1945       0.58      0.50      0.54      3246
#         1950       0.58      0.60      0.59      3275
#         1955       0.53      0.56      0.55      3245
#         1960       0.54      0.54      0.54      3179
#         1965       0.57      0.57      0.57      3259
#         1970       0.62      0.61      0.61      3186
#         1975       0.50      0.50      0.50      3204
#         1980       0.51      0.47      0.49      3220
#         1985       0.63      0.67      0.65      3222
#         1990       0.56      0.59      0.58      3200
#
#     accuracy                           0.56     32236
#    macro avg       0.56      0.56      0.56     32236
# weighted avg       0.56      0.56      0.56     32236
#
# (322360, 988) 10
# Combination 8 Training feature category: ['W2V', 'Radical']
# len of x_feature: 610
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.5969589238056784
# macro precision_score ::  0.5982
# micro precision_score ::  0.597
# macro recall_score ::  0.597
# micro recall_score ::  0.597
# macro F1_score ::  0.5968
# micro F1_score ::  0.597
# dataset 有203086個名字 74587種名字
# Multi_Train Accuracy:: 0.9997242547492196
# 平均年份絕對值誤差:: 0.0034812837911032766
# report:
#                precision    recall  f1-score   support
#
#         1945       0.65      0.67      0.66     20154
#         1950       0.59      0.62      0.60     20357
#         1955       0.61      0.58      0.59     20368
#         1960       0.59      0.57      0.58     20391
#         1965       0.53      0.60      0.56     20267
#         1970       0.55      0.58      0.57     20313
#         1975       0.57      0.53      0.55     20270
#         1980       0.61      0.54      0.57     20297
#         1985       0.64      0.59      0.62     20277
#         1990       0.66      0.68      0.67     20392
#
#     accuracy                           0.60    203086
#    macro avg       0.60      0.60      0.60    203086
# weighted avg       0.60      0.60      0.60    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.30405110411544384
# macro precision_score ::  0.2993
# micro precision_score ::  0.3041
# macro recall_score ::  0.3042
# micro recall_score ::  0.3041
# macro F1_score ::  0.3009
# micro F1_score ::  0.3041
# dataset 有87038個名字 43291種名字
# Multi_Test Accuracy:: 0.6070222201796917
# 平均年份絕對值誤差:: 3.9842712378501344
# report:
#                precision    recall  f1-score   support
#
#         1945       0.37      0.41      0.39      8749
#         1950       0.33      0.35      0.34      8676
#         1955       0.30      0.29      0.30      8668
#         1960       0.30      0.28      0.29      8677
#         1965       0.33      0.36      0.34      8717
#         1970       0.37      0.38      0.38      8688
#         1975       0.22      0.18      0.20      8701
#         1980       0.21      0.18      0.19      8743
#         1985       0.25      0.23      0.24      8789
#         1990       0.32      0.37      0.34      8630
#
#     accuracy                           0.30     87038
#    macro avg       0.30      0.30      0.30     87038
# weighted avg       0.30      0.30      0.30     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.30763742399801464
# macro precision_score ::  0.303
# micro precision_score ::  0.3076
# macro recall_score ::  0.3071
# micro recall_score ::  0.3076
# macro F1_score ::  0.3043
# micro F1_score ::  0.3076
# dataset 有32236個名字 20838種名字
# Multi_Development Accuracy:: 0.5050564586176945
# 平均年份絕對值誤差:: 5.126597592753443
# report:
#                precision    recall  f1-score   support
#
#         1945       0.38      0.42      0.40      3333
#         1950       0.32      0.35      0.33      3203
#         1955       0.31      0.30      0.30      3200
#         1960       0.32      0.30      0.31      3168
#         1965       0.33      0.36      0.35      3252
#         1970       0.38      0.38      0.38      3235
#         1975       0.22      0.19      0.20      3265
#         1980       0.21      0.17      0.19      3196
#         1985       0.25      0.24      0.24      3170
#         1990       0.31      0.37      0.34      3214
#
#     accuracy                           0.31     32236
#    macro avg       0.30      0.31      0.30     32236
# weighted avg       0.30      0.31      0.30     32236
#
# (322360, 988) 10
# Combination 9 Training feature category: ['Phonetic', 'Fortune_map']
# len of x_feature: 355
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.7369636508671203
# macro precision_score ::  0.7374
# micro precision_score ::  0.737
# macro recall_score ::  0.7369
# micro recall_score ::  0.737
# macro F1_score ::  0.7365
# micro F1_score ::  0.737
# dataset 有203086個名字 74511種名字
# Multi_Train Accuracy:: 0.9608638704785165
# 平均年份絕對值誤差:: 0.3756635120096905
# report:
#                precision    recall  f1-score   support
#
#         1945       0.82      0.83      0.83     20403
#         1950       0.80      0.80      0.80     20217
#         1955       0.80      0.77      0.78     20396
#         1960       0.77      0.75      0.76     20216
#         1965       0.72      0.76      0.74     20314
#         1970       0.69      0.77      0.73     20434
#         1975       0.71      0.65      0.68     20296
#         1980       0.68      0.65      0.67     20225
#         1985       0.69      0.66      0.68     20310
#         1990       0.69      0.74      0.71     20275
#
#     accuracy                           0.74    203086
#    macro avg       0.74      0.74      0.74    203086
# weighted avg       0.74      0.74      0.74    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.3387026356304143
# macro precision_score ::  0.3331
# micro precision_score ::  0.3387
# macro recall_score ::  0.339
# micro recall_score ::  0.3387
# macro F1_score ::  0.3355
# micro F1_score ::  0.3387
# dataset 有87038個名字 43409種名字
# Multi_Test Accuracy:: 0.582722489027781
# 平均年份絕對值誤差:: 4.3895654771479125
# report:
#                precision    recall  f1-score   support
#
#         1945       0.41      0.46      0.44      8627
#         1950       0.39      0.40      0.39      8691
#         1955       0.36      0.36      0.36      8627
#         1960       0.36      0.35      0.35      8760
#         1965       0.40      0.42      0.41      8790
#         1970       0.43      0.48      0.45      8663
#         1975       0.20      0.17      0.19      8645
#         1980       0.22      0.20      0.21      8879
#         1985       0.24      0.23      0.24      8700
#         1990       0.30      0.33      0.32      8656
#
#     accuracy                           0.34     87038
#    macro avg       0.33      0.34      0.34     87038
# weighted avg       0.33      0.34      0.34     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.3435910162551185
# macro precision_score ::  0.338
# micro precision_score ::  0.3436
# macro recall_score ::  0.344
# micro recall_score ::  0.3436
# macro F1_score ::  0.3405
# micro F1_score ::  0.3436
# dataset 有32236個名字 20830種名字
# Multi_Development Accuracy:: 0.5017061670182404
# 平均年份絕對值誤差:: 5.360652686437524
# report:
#                precision    recall  f1-score   support
#
#         1945       0.43      0.47      0.45      3206
#         1950       0.40      0.41      0.40      3328
#         1955       0.36      0.36      0.36      3213
#         1960       0.36      0.36      0.36      3260
#         1965       0.39      0.42      0.40      3132
#         1970       0.44      0.48      0.46      3139
#         1975       0.23      0.19      0.20      3295
#         1980       0.22      0.20      0.21      3132
#         1985       0.24      0.23      0.24      3226
#         1990       0.32      0.33      0.32      3305
#
#     accuracy                           0.34     32236
#    macro avg       0.34      0.34      0.34     32236
# weighted avg       0.34      0.34      0.34     32236
#
# (322360, 988) 10
# Combination 10 Training feature category: ['Phonetic', 'Zodiac']
# len of x_feature: 340
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.7966526496164187
# macro precision_score ::  0.7972
# micro precision_score ::  0.7967
# macro recall_score ::  0.7966
# micro recall_score ::  0.7967
# macro F1_score ::  0.7967
# micro F1_score ::  0.7967
# dataset 有203086個名字 74406種名字
# Multi_Train Accuracy:: 0.9358843051712082
# 平均年份絕對值誤差:: 0.7765478664211221
# report:
#                precision    recall  f1-score   support
#
#         1945       0.85      0.80      0.82     20352
#         1950       0.82      0.82      0.82     20354
#         1955       0.80      0.79      0.80     20269
#         1960       0.80      0.81      0.81     20157
#         1965       0.75      0.79      0.77     20314
#         1970       0.76      0.80      0.78     20206
#         1975       0.77      0.76      0.76     20244
#         1980       0.78      0.76      0.77     20397
#         1985       0.84      0.83      0.83     20433
#         1990       0.79      0.80      0.80     20360
#
#     accuracy                           0.80    203086
#    macro avg       0.80      0.80      0.80    203086
# weighted avg       0.80      0.80      0.80    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.49858682414577543
# macro precision_score ::  0.4982
# micro precision_score ::  0.4986
# macro recall_score ::  0.4986
# micro recall_score ::  0.4986
# macro F1_score ::  0.4979
# micro F1_score ::  0.4986
# dataset 有87038個名字 43233種名字
# Multi_Test Accuracy:: 0.6558169994714952
# 平均年份絕對值誤差:: 4.782141133757669
# report:
#                precision    recall  f1-score   support
#
#         1945       0.52      0.44      0.48      8648
#         1950       0.52      0.53      0.53      8686
#         1955       0.47      0.48      0.48      8748
#         1960       0.50      0.50      0.50      8792
#         1965       0.49      0.52      0.50      8726
#         1970       0.54      0.56      0.55      8807
#         1975       0.45      0.44      0.44      8731
#         1980       0.44      0.43      0.44      8658
#         1985       0.54      0.56      0.55      8600
#         1990       0.50      0.52      0.51      8642
#
#     accuracy                           0.50     87038
#    macro avg       0.50      0.50      0.50     87038
# weighted avg       0.50      0.50      0.50     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.49674277205608636
# macro precision_score ::  0.4968
# micro precision_score ::  0.4967
# macro recall_score ::  0.4968
# micro recall_score ::  0.4967
# macro F1_score ::  0.4964
# micro F1_score ::  0.4967
# dataset 有32236個名字 20946種名字
# Multi_Development Accuracy:: 0.5946457376845763
# 平均年份絕對值誤差:: 5.821224717706912
# report:
#                precision    recall  f1-score   support
#
#         1945       0.53      0.45      0.48      3236
#         1950       0.51      0.53      0.52      3196
#         1955       0.48      0.48      0.48      3219
#         1960       0.49      0.50      0.50      3287
#         1965       0.49      0.51      0.50      3196
#         1970       0.53      0.55      0.54      3223
#         1975       0.44      0.44      0.44      3261
#         1980       0.45      0.44      0.44      3181
#         1985       0.54      0.55      0.55      3203
#         1990       0.50      0.52      0.51      3234
#
#     accuracy                           0.50     32236
#    macro avg       0.50      0.50      0.50     32236
# weighted avg       0.50      0.50      0.50     32236
#
# (322360, 988) 10
# Combination 11 Training feature category: ['Phonetic', 'Radical']
# len of x_feature: 738
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.5877805461725575
# macro precision_score ::  0.589
# micro precision_score ::  0.5878
# macro recall_score ::  0.5878
# micro recall_score ::  0.5878
# macro F1_score ::  0.5876
# micro F1_score ::  0.5878
# dataset 有203086個名字 74237種名字
# Multi_Train Accuracy:: 0.9906689776744827
# 平均年份絕對值誤差:: 0.10001674167594024
# report:
#                precision    recall  f1-score   support
#
#         1945       0.64      0.66      0.65     20270
#         1950       0.59      0.62      0.60     20380
#         1955       0.59      0.58      0.58     20358
#         1960       0.58      0.55      0.57     20388
#         1965       0.52      0.59      0.55     20441
#         1970       0.53      0.59      0.56     20249
#         1975       0.58      0.51      0.54     20320
#         1980       0.58      0.54      0.56     20183
#         1985       0.62      0.59      0.60     20245
#         1990       0.66      0.66      0.66     20252
#
#     accuracy                           0.59    203086
#    macro avg       0.59      0.59      0.59    203086
# weighted avg       0.59      0.59      0.59    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.2982145729451504
# macro precision_score ::  0.2941
# micro precision_score ::  0.2982
# macro recall_score ::  0.2985
# micro recall_score ::  0.2982
# macro F1_score ::  0.2958
# micro F1_score ::  0.2982
# dataset 有87038個名字 43311種名字
# Multi_Test Accuracy:: 0.602012913899676
# 平均年份絕對值誤差:: 4.1656173165743695
# report:
#                precision    recall  f1-score   support
#
#         1945       0.37      0.41      0.39      8644
#         1950       0.32      0.34      0.33      8596
#         1955       0.30      0.29      0.29      8712
#         1960       0.30      0.28      0.29      8692
#         1965       0.32      0.35      0.33      8613
#         1970       0.36      0.38      0.37      8800
#         1975       0.21      0.18      0.19      8748
#         1980       0.21      0.18      0.20      8809
#         1985       0.25      0.23      0.24      8695
#         1990       0.32      0.33      0.32      8729
#
#     accuracy                           0.30     87038
#    macro avg       0.29      0.30      0.30     87038
# weighted avg       0.29      0.30      0.30     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.2947636183149274
# macro precision_score ::  0.2903
# micro precision_score ::  0.2948
# macro recall_score ::  0.2945
# micro recall_score ::  0.2948
# macro F1_score ::  0.292
# micro F1_score ::  0.2948
# dataset 有32236個名字 20918種名字
# Multi_Development Accuracy:: 0.48867725524258593
# 平均年份絕對值誤差:: 5.330189849857303
# report:
#                precision    recall  f1-score   support
#
#         1945       0.38      0.41      0.39      3322
#         1950       0.33      0.34      0.33      3260
#         1955       0.29      0.29      0.29      3166
#         1960       0.29      0.28      0.29      3156
#         1965       0.32      0.36      0.34      3182
#         1970       0.36      0.38      0.37      3187
#         1975       0.20      0.18      0.19      3168
#         1980       0.19      0.17      0.18      3244
#         1985       0.24      0.23      0.23      3296
#         1990       0.31      0.32      0.31      3255
#
#     accuracy                           0.29     32236
#    macro avg       0.29      0.29      0.29     32236
# weighted avg       0.29      0.29      0.29     32236
#
# (322360, 988) 10
# Combination 12 Training feature category: ['Fortune_map', 'Zodiac']
# len of x_feature: 39
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  203086
# Finished training
# Train metrics
# Train_x len = 203086
# Finished prdeiction
# Accuracy ::  0.3835616438356164
# macro precision_score ::  0.3817
# micro precision_score ::  0.3836
# macro recall_score ::  0.3835
# micro recall_score ::  0.3836
# macro F1_score ::  0.3723
# micro F1_score ::  0.3836
# dataset 有203086個名字 74736種名字
# Multi_Train Accuracy:: 0.5879381148872891
# 平均年份絕對值誤差:: 5.528953251331948
# report:
#                precision    recall  f1-score   support
#
#         1945       0.37      0.17      0.24     20312
#         1950       0.40      0.42      0.41     20317
#         1955       0.35      0.49      0.41     20297
#         1960       0.38      0.43      0.40     20301
#         1965       0.35      0.27      0.31     20250
#         1970       0.34      0.27      0.30     20394
#         1975       0.39      0.33      0.36     20276
#         1980       0.41      0.28      0.33     20254
#         1985       0.43      0.58      0.50     20409
#         1990       0.39      0.58      0.47     20276
#
#     accuracy                           0.38    203086
#    macro avg       0.38      0.38      0.37    203086
# weighted avg       0.38      0.38      0.37    203086
#
# Test metrics
# Test_x len = 203086
# Finished prdeiction
# Accuracy ::  0.3535697051862405
# macro precision_score ::  0.3489
# micro precision_score ::  0.3536
# macro recall_score ::  0.3535
# micro recall_score ::  0.3536
# macro F1_score ::  0.3421
# micro F1_score ::  0.3536
# dataset 有87038個名字 43292種名字
# Multi_Test Accuracy:: 0.5098692525103977
# 平均年份絕對值誤差:: 6.862278545003332
# report:
#                precision    recall  f1-score   support
#
#         1945       0.31      0.15      0.20      8726
#         1950       0.36      0.38      0.37      8694
#         1955       0.31      0.43      0.36      8729
#         1960       0.33      0.37      0.35      8662
#         1965       0.32      0.25      0.28      8722
#         1970       0.29      0.23      0.26      8661
#         1975       0.37      0.32      0.34      8709
#         1980       0.39      0.27      0.32      8710
#         1985       0.42      0.58      0.49      8656
#         1990       0.38      0.56      0.46      8769
#
#     accuracy                           0.35     87038
#    macro avg       0.35      0.35      0.34     87038
# weighted avg       0.35      0.35      0.34     87038
#
# Development metrics
# Development_x len = 203086
# Finished prdeiction
# Accuracy ::  0.35559622781982875
# macro precision_score ::  0.3505
# micro precision_score ::  0.3556
# macro recall_score ::  0.3562
# micro recall_score ::  0.3556
# macro F1_score ::  0.3434
# micro F1_score ::  0.3556
# ...
#   'FN2_wv_49',
#   'FN1_wv_50',
#   'FN2_wv_50',
#   'FN1_wv_51',
#   'FN2_wv_51',
#   'FN1_wv_52',
#   'FN2_wv_52',
#   'FN1_wv_53',
#   'FN2_wv_53',
#   'FN1_wv_54',
#   'FN2_wv_54',
#   'FN1_wv_55',
#   'FN2_wv_55',
#   'FN1_wv_56',
#   'FN2_wv_56',
#   'FN1_wv_57',
#   'FN2_wv_57',
#   'FN1_wv_58',
#   'FN2_wv_58',
#   'FN1_wv_59',
#   'FN2_wv_59',
#   'FN1_wv_60',
#   'FN2_wv_60',
#   'FN1_wv_61',
#   'FN2_wv_61',
#   'FN1_wv_62',
#   'FN2_wv_62',
#   'FN1_wv_63',
#   'FN2_wv_63',
#   'FN1_wv_64',
#   'FN2_wv_64',
#   'FN1_wv_65',
#   'FN2_wv_65',
#   'FN1_wv_66',
#   'FN2_wv_66',
#   'FN1_wv_67',
#   'FN2_wv_67',
#   'FN1_wv_68',
#   'FN2_wv_68',
#   'FN1_wv_69',
#   'FN2_wv_69',
#   'FN1_wv_70',
#   'FN2_Radical_齒',
#   'FN2_Radical_龍',
#   'FN2_Radical_龠',
#   'Zodiac_兔',
#   'Zodiac_牛',
#   'Zodiac_狗',
#   'Zodiac_猴',
#   'Zodiac_羊',
#   'Zodiac_虎',
#   'Zodiac_蛇',
#   'Zodiac_豬',
#   'Zodiac_雞',
#   'Zodiac_馬',
#   'Zodiac_鼠',
#   'Zodiac_龍',
#   'FN1_Vowel_',
#   'FN1_Vowel_e',
#   'FN1_Vowel_en',
#   'FN1_Vowel_uǎ',
#   'FN2_Vowel_en',
#   'FN2_Vowel_uǎi'])

# %%
sampled_df = sample_name_df(name_df, sample_number, birth_years, True)
print("Dataset shape", sampled_df.shape, len(birth_years))
# Out:
# Dataset shape (322360, 988) 10

# %%
sampled_df['BirthYear'].value_counts()
# Out:
# 10    32236
# 9     32236
# 8     32236
# 7     32236
# 6     32236
# 5     32236
# 4     32236
# 3     32236
# 2     32236
# 1     32236
# Name: BirthYear, dtype: int64

# %% [markdown]
# (5-2B)Training for all combination - baseline dataset

# %%
birth_year_base = BIRTH_YEAR_BASE + head * 5  
birth_years = [i for i in range(head, tail + 1)]  # for index to 1945 ~ 1994
sample_number = name_df["BirthYear"].value_counts().min()
target_names = [str(i) for i in range(birth_year_base, BIRTH_YEAR_BASE + tail * 5 + 5, 5)]
save_path = plib_path("./Training/Real_Base/")
validation_times = 3
do_first_name_augmentation = False
model_name = "Taiwan_name_RFC"
estimators_num = 64
min_samples_leaf_num = 1

train_birth_year_model(name_df, do_first_name_augmentation, validation_times,
                           feature_combinations, BIRTH_YEAR_BASE, target_names,
                           save_path, model_name, birth_years, sample_number,
                           estimators_num, min_samples_leaf_num)
# Out:
# (294470, 3367) 10
# Combination 0 Training feature category: ['W2V']
# len of x_feature: 200
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  185516
# Finished training
# Train metrics
# Train_x len = 185516
# Finished prdeiction
# Accuracy ::  0.5957976670475862
# macro precision_score ::  0.5963
# micro precision_score ::  0.5958
# macro recall_score ::  0.5958
# micro recall_score ::  0.5958
# macro F1_score ::  0.5958
# micro F1_score ::  0.5958
# dataset 有185516個名字 57623種名字
# Multi_Train Accuracy:: 0.9997682140623989
# 平均年份絕對值誤差:: 0.004382371331852778
# report:
#                precision    recall  f1-score   support
#
#         1945       0.61      0.64      0.62     18581
#         1950       0.60      0.60      0.60     18488
#         1955       0.58      0.58      0.58     18529
#         1960       0.58      0.54      0.56     18545
#         1965       0.53      0.55      0.54     18604
#         1970       0.53      0.55      0.54     18645
#         1975       0.59      0.57      0.58     18520
#         1980       0.61      0.59      0.60     18580
#         1985       0.65      0.64      0.65     18500
#         1990       0.68      0.70      0.69     18524
#
#     accuracy                           0.60    185516
#    macro avg       0.60      0.60      0.60    185516
# weighted avg       0.60      0.60      0.60    185516
#
# Test metrics
# Test_x len = 185516
# Finished prdeiction
# Accuracy ::  0.3645087853899657
# macro precision_score ::  0.3629
# micro precision_score ::  0.3645
# macro recall_score ::  0.3643
# micro recall_score ::  0.3645
# macro F1_score ::  0.3632
# micro F1_score ::  0.3645
# dataset 有79507個名字 35955種名字
# Multi_Test Accuracy:: 0.6933226005257399
# 平均年份絕對值誤差:: 3.743267888362031
# report:
#                precision    recall  f1-score   support
#
#         1945       0.38      0.43      0.40      7954
#         1950       0.37      0.37      0.37      8005
#         1955       0.35      0.35      0.35      7943
#         1960       0.35      0.31      0.33      7907
#         1965       0.32      0.32      0.32      7879
#         1970       0.34      0.34      0.34      7920
#         1975       0.33      0.31      0.32      7948
#         1980       0.36      0.34      0.35      7950
#         1985       0.39      0.39      0.39      7975
#         1990       0.43      0.48      0.46      8026
#
#     accuracy                           0.36     79507
#    macro avg       0.36      0.36      0.36     79507
# weighted avg       0.36      0.36      0.36     79507
#
# Development metrics
# Development_x len = 185516
# Finished prdeiction
# Accuracy ::  0.361734641899005
# macro precision_score ::  0.3605
# micro precision_score ::  0.3617
# macro recall_score ::  0.3621
# micro recall_score ::  0.3617
# macro F1_score ::  0.3608
# micro F1_score ::  0.3617
# dataset 有29447個名字 18063種名字
# Multi_Development Accuracy:: 0.5815532991476211
# 平均年份絕對值誤差:: 5.181784222501443
# report:
#                precision    recall  f1-score   support
#
#         1945       0.39      0.43      0.41      2912
#         1950       0.37      0.38      0.37      2954
#         1955       0.34      0.34      0.34      2975
#         1960       0.35      0.31      0.33      2995
#         1965       0.32      0.31      0.31      2964
#         1970       0.32      0.33      0.33      2882
#         1975       0.35      0.32      0.33      2979
#         1980       0.35      0.34      0.34      2917
#         1985       0.40      0.40      0.40      2972
#         1990       0.42      0.47      0.44      2897
#
#     accuracy                           0.36     29447
#    macro avg       0.36      0.36      0.36     29447
# weighted avg       0.36      0.36      0.36     29447
#
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  185516
# Finished training
# Train metrics
# Train_x len = 185516
# Finished prdeiction
# Accuracy ::  0.5954041699907285
# macro precision_score ::  0.5956
# micro precision_score ::  0.5954
# macro recall_score ::  0.5953
# micro recall_score ::  0.5954
# macro F1_score ::  0.5953
# micro F1_score ::  0.5954
# dataset 有185516個名字 57570種名字
# Multi_Train Accuracy:: 0.9996981392440544
# 平均年份絕對值誤差:: 0.004527911339183682
# report:
#                precision    recall  f1-score   support
#
#         1945       0.62      0.63      0.63     18525
#         1950       0.57      0.61      0.59     18573
#         1955       0.59      0.58      0.58     18523
#         1960       0.57      0.55      0.56     18470
#         1965       0.53      0.55      0.54     18561
#         1970       0.55      0.54      0.54     18478
#         1975       0.59      0.56      0.58     18692
#         1980       0.60      0.59      0.60     18492
#         1985       0.65      0.63      0.64     18571
#         1990       0.68      0.70      0.69     18631
#
#     accuracy                           0.60    185516
#    macro avg       0.60      0.60      0.60    185516
# weighted avg       0.60      0.60      0.60    185516
#
# Test metrics
# Test_x len = 185516
# Finished prdeiction
# Accuracy ::  0.36372897983825325
# macro precision_score ::  0.3629
# micro precision_score ::  0.3637
# macro recall_score ::  0.364
# micro recall_score ::  0.3637
# macro F1_score ::  0.363
# micro F1_score ::  0.3637
# dataset 有79507個名字 36065種名字
# Multi_Test Accuracy:: 0.6929704302765795
# 平均年份絕對值誤差:: 3.778912548580628
# report:
#                precision    recall  f1-score   support
#
#         1945       0.38      0.41      0.39      7979
#         1950       0.34      0.37      0.36      7885
#         1955       0.35      0.35      0.35      7972
#         1960       0.34      0.32      0.33      7987
#         1965       0.32      0.32      0.32      7998
#         1970       0.35      0.32      0.34      8002
#         1975       0.35      0.33      0.34      7922
#         1980       0.36      0.34      0.35      8004
#         1985       0.39      0.39      0.39      7904
#         1990       0.43      0.48      0.45      7854
#
#     accuracy                           0.36     79507
#    macro avg       0.36      0.36      0.36     79507
# weighted avg       0.36      0.36      0.36     79507
#
# Development metrics
# Development_x len = 185516
# Finished prdeiction
# Accuracy ::  0.36883213909736134
# macro precision_score ::  0.3674
# micro precision_score ::  0.3688
# macro recall_score ::  0.3685
# micro recall_score ::  0.3688
# macro F1_score ::  0.3676
# micro F1_score ::  0.3688
# dataset 有29447個名字 18305種名字
# Multi_Development Accuracy:: 0.5799572112609094
# 平均年份絕對值誤差:: 5.1774034706421705
# report:
#                precision    recall  f1-score   support
#
#         1945       0.39      0.41      0.40      2943
#         1950       0.36      0.40      0.38      2989
#         1955       0.35      0.35      0.35      2952
#         1960       0.36      0.33      0.34      2990
#         1965       0.31      0.32      0.31      2888
#         1970       0.34      0.31      0.33      2967
#         1975       0.34      0.32      0.33      2833
#         1980       0.36      0.34      0.35      2951
#         1985       0.41      0.41      0.41      2972
#         1990       0.45      0.50      0.47      2962
#
#     accuracy                           0.37     29447
#    macro avg       0.37      0.37      0.37     29447
# weighted avg       0.37      0.37      0.37     29447
#
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  185516
# Finished training
# Train metrics
# Train_x len = 185516
# Finished prdeiction
# Accuracy ::  0.5968002759869768
# macro precision_score ::  0.597
# micro precision_score ::  0.5968
# macro recall_score ::  0.5968
# micro recall_score ::  0.5968
# macro F1_score ::  0.5968
# micro F1_score ::  0.5968
# dataset 有185516個名字 57655種名字
# Multi_Train Accuracy:: 0.9997843851743246
# 平均年份絕對值誤差:: 0.004290735030940728
# report:
#                precision    recall  f1-score   support
#
#         1945       0.62      0.64      0.63     18761
#         1950       0.59      0.61      0.60     18515
#         1955       0.59      0.57      0.58     18523
#         1960       0.57      0.56      0.56     18511
#         1965       0.53      0.55      0.54     18422
#         1970       0.54      0.55      0.54     18579
#         1975       0.59      0.56      0.58     18520
#         1980       0.61      0.59      0.60     18648
#         1985       0.65      0.64      0.64     18574
#         1990       0.68      0.70      0.69     18463
#
#     accuracy                           0.60    185516
#    macro avg       0.60      0.60      0.60    185516
# weighted avg       0.60      0.60      0.60    185516
#
# Test metrics
# Test_x len = 185516
# Finished prdeiction
# Accuracy ::  0.36210648119033545
# macro precision_score ::  0.361
# micro precision_score ::  0.3621
# macro recall_score ::  0.3622
# micro recall_score ::  0.3621
# macro F1_score ::  0.3613
# micro F1_score ::  0.3621
# dataset 有79507個名字 35925種名字
# Multi_Test Accuracy:: 0.6957374822342687
# 平均年份絕對值誤差:: 3.702353251914926
# report:
#                precision    recall  f1-score   support
#
#         1945       0.38      0.43      0.40      7760
#         1950       0.36      0.37      0.36      7994
#         1955       0.36      0.34      0.35      8055
#         1960       0.33      0.32      0.32      7959
#         1965       0.32      0.32      0.32      8008
#         1970       0.33      0.32      0.33      7863
#         1975       0.34      0.32      0.33      7936
#         1980       0.37      0.35      0.36      7946
#         1985       0.39      0.39      0.39      7994
#         1990       0.44      0.47      0.45      7992
#
#     accuracy                           0.36     79507
#    macro avg       0.36      0.36      0.36     79507
# weighted avg       0.36      0.36      0.36     79507
#
# Development metrics
# Development_x len = 185516
# Finished prdeiction
# Accuracy ::  0.36316093320202397
# macro precision_score ::  0.3617
# micro precision_score ::  0.3632
# macro recall_score ::  0.3632
# micro recall_score ::  0.3632
# macro F1_score ::  0.3621
# micro F1_score ::  0.3632
# dataset 有29447個名字 18153種名字
# Multi_Development Accuracy:: 0.5742860053655721
# 平均年份絕對值誤差:: 5.273270621795089
# report:
#                precision    recall  f1-score   support
#
#         1945       0.38      0.41      0.39      2926
#         1950       0.37      0.40      0.38      2938
#         1955       0.35      0.33      0.34      2869
#         1960       0.35      0.32      0.33      2977
#         1965       0.32      0.32      0.32      3017
#         1970       0.35      0.33      0.34      3005
#         1975       0.33      0.31      0.32      2991
#         1980       0.34      0.34      0.34      2853
#         1985       0.38      0.39      0.39      2879
#         1990       0.45      0.48      0.46      2992
#
#     accuracy                           0.36     29447
#    macro avg       0.36      0.36      0.36     29447
# weighted avg       0.36      0.36      0.36     29447
#
# (294470, 3367) 10
# Combination 1 Training feature category: ['Phonetic']
# len of x_feature: 0
# estimators_num =  64 min_samples_leaf_num =  1 Training Data len =  185516
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-09c1e485a0fb> in <module>
#      10 min_samples_leaf_num = 1
#      11
# ---> 12 train_birth_year_model(name_df, do_first_name_augmentation, validation_times,
#      13                            feature_combinations, birth_year_base, target_names,
#      14                            save_path, model_name, birth_years, sample_number,
#
# <ipython-input-20-e3f05bb44243> in train_birth_year_model(name_df, do_first_name_augmentation, validation_times, feature_combinations, birth_year_base, target_names, save_path, model_name, birth_years, sample_number, estimators_num, min_samples_leaf_num)
#      56                     sampled_df.drop(dev_df.index), 0.7, x_feature, y_feature)
#      57             # Create random forest classifier instance
# ---> 58             trained_model = random_forest_classifier(
#      59                 train_x, train_y.values.reshape(-1, 1).ravel(), estimators_num, min_samples_leaf_num)
#      60             print('Finished training')
#
# d:\code\Behind_Names\Taiwan_Name_Experiment\name_module\training_module.py in random_forest_classifier(features, target, estimators_num, min_samples_leaf_num)
#     150     print('estimators_num = ', estimators_num, 'min_samples_leaf_num = ',
#     151           min_samples_leaf_num, "Training Data len = ", len(features))
# --> 152     clf.fit(features, target)
#     153     return clf
#     154
#
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     301                 "sparse multilabel-indicator for y is not supported."
#     302             )
# --> 303         X, y = self._validate_data(X, y, multi_output=True,
#     304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\Users\n7912\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     531
#     532         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 533             dtype_orig = np.result_type(*dtypes_orig)
#     534
#     535     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# ValueError: at least one array or dtype is required
